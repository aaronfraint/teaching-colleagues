# %% [markdown]
# # Use the `pandas` module to access data from a variety of sources
#
# In this example we're fetching a `.xlsx` file from the web, but you can also load `.csv` and other file types from disk.
#
# By convention, `pandas` is often imported "`as pd`" and once you do this you utilize the library using `pd.function()`

# %%
import pandas as pd

# %% [markdown]
# ### Define a URL or filepath and use `pd.read_csv()` or `pd.read_excel()`
#
# By convention, the `DataFrame` created by `pandas` is stored in an object called `df`
#
# This convention is only applicable if you have a single dataframe in use. If you're working with multiple dataframes you'll need to find a better naming approach.

# %%
url = 'https://www1.nyc.gov/assets/nypd/downloads/excel/analysis_and_planning/stop-question-frisk/sqf-2018.xlsx'

df = pd.read_excel(url)

# %% [markdown]
# ### Once you've created a dataframe you can use any `pandas` operation on it
#
# #### Common initial steps include looking at the `.head()` or `.tail()` of the dataframe (i.e. first or last 5 rows of data)

# %%
df.head()
# Out:
#    STOP_FRISK_ID STOP_FRISK_DATE Stop Frisk Time  YEAR2   MONTH2    DAY2  \
# 0              1      2018-01-01        19:04:00   2018  January  Monday
# 1              2      2018-01-01        23:00:00   2018  January  Monday
# 2              3      2018-01-01        23:55:00   2018  January  Monday
# 3              4      2018-01-01        03:23:00   2018  January  Monday
# 4              5      2018-01-01        03:23:00   2018  January  Monday
#
#       STOP_WAS_INITIATED RECORD_STATUS_CODE ISSUING_OFFICER_RANK  \
# 0  Based on C/W on Scene                APP                  POM
# 1     Based on Radio Run                APP                  POM
# 2     Based on Radio Run                APP                  POM
# 3     Based on Radio Run                APP                  POM
# 4     Based on Radio Run                APP                  POM
#
#    ISSUING_OFFICER_COMMAND_CODE  ... STOP_LOCATION_SECTOR_CODE  \
# 0                             1  ...                         G
# 1                            34  ...                         C
# 2                           808  ...                         B
# 3                            63  ...                         B
# 4                            63  ...                         B
#
#    STOP_LOCATION_APARTMENT        STOP_LOCATION_FULL_ADDRESS  \
# 0                   (null)  VARICK STREET && FRANKLIN STREET
# 1                   (null)     DYCKMAN STREET && POST AVENUE
# 2                       4M               2245 RANDALL AVENUE
# 3                   (null)        EAST 38 STREET && AVENUE L
# 4                   (null)        EAST 38 STREET && AVENUE L
#
#   STOP_LOCATION_PREMISES_NAME STOP_LOCATION_STREET_NAME STOP_LOCATION_X  \
# 0                      (null)             VARICK STREET          982327
# 1                      (null)            DYCKMAN STREET         1004892
# 2                      (null)            RANDALL AVENUE         1026706
# 3                      (null)            EAST 38 STREET         1001347
# 4                      (null)            EAST 38 STREET         1001347
#
#    STOP_LOCATION_Y STOP_LOCATION_ZIP_CODE  STOP_LOCATION_PATROL_BORO_NAME  \
# 0           201274                 (null)                            PBMS
# 1           253548                 (null)                            PBMN
# 2           237776                 (null)                            PBBX
# 3           166195                 (null)                            PBBS
# 4           166195                 (null)                            PBBS
#
#   STOP_LOCATION_BORO_NAME
# 0               MANHATTAN
# 1               MANHATTAN
# 2                   BRONX
# 3                BROOKLYN
# 4                BROOKLYN
#
# [5 rows x 83 columns]

# %% [markdown]
# #### You can use `df.columns` or `df.dtypes` to learn more about the structure of your data

# %%
df.dtypes
# Out:
# STOP_FRISK_ID                              int64
# STOP_FRISK_DATE                   datetime64[ns]
# Stop Frisk Time                           object
# YEAR2                                      int64
# MONTH2                                    object
#                                        ...
# STOP_LOCATION_X                            int64
# STOP_LOCATION_Y                            int64
# STOP_LOCATION_ZIP_CODE                    object
# STOP_LOCATION_PATROL_BORO_NAME            object
# STOP_LOCATION_BORO_NAME                   object
# Length: 83, dtype: object

# %% [markdown]
# #### It can also be helpful sometimes to rotate your data by 90 degrees
#
# This is done using `df.T` to "transpose" the data

# %%
df.head().T
# Out:
#                                                   0                    1  \
# STOP_FRISK_ID                                     1                    2
# STOP_FRISK_DATE                 2018-01-01 00:00:00  2018-01-01 00:00:00
# Stop Frisk Time                            19:04:00             23:00:00
# YEAR2                                          2018                 2018
# MONTH2                                      January              January
# ...                                             ...                  ...
# STOP_LOCATION_X                              982327              1004892
# STOP_LOCATION_Y                              201274               253548
# STOP_LOCATION_ZIP_CODE                       (null)               (null)
# STOP_LOCATION_PATROL_BORO_NAME                 PBMS                 PBMN
# STOP_LOCATION_BORO_NAME                   MANHATTAN            MANHATTAN
#
#                                                   2                    3  \
# STOP_FRISK_ID                                     3                    4
# STOP_FRISK_DATE                 2018-01-01 00:00:00  2018-01-01 00:00:00
# Stop Frisk Time                            23:55:00             03:23:00
# YEAR2                                          2018                 2018
# MONTH2                                      January              January
# ...                                             ...                  ...
# STOP_LOCATION_X                             1026706              1001347
# STOP_LOCATION_Y                              237776               166195
# STOP_LOCATION_ZIP_CODE                       (null)               (null)
# STOP_LOCATION_PATROL_BORO_NAME                 PBBX                 PBBS
# STOP_LOCATION_BORO_NAME                       BRONX             BROOKLYN
#
#                                                   4
# STOP_FRISK_ID                                     5
# STOP_FRISK_DATE                 2018-01-01 00:00:00
# Stop Frisk Time                            03:23:00
# YEAR2                                          2018
# MONTH2                                      January
# ...                                             ...
# STOP_LOCATION_X                             1001347
# STOP_LOCATION_Y                              166195
# STOP_LOCATION_ZIP_CODE                       (null)
# STOP_LOCATION_PATROL_BORO_NAME                 PBBS
# STOP_LOCATION_BORO_NAME                    BROOKLYN
#
# [83 rows x 5 columns]
